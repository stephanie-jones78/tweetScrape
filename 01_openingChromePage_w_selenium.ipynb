# %%
# testing to see if have selenium
import selenium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-abb2a9e03f2a> in <module>
# ----> 1 import selenium
#
# ModuleNotFoundError: No module named 'selenium'

# %%
# nope, installing seleniumimport 
# !pip install selenium
# Out:
# ...
#      |████████████████████████████████| 985 kB 2.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 160 kB 20.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 358 kB 29.7 MB/s eta 0:00:01
# ...
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.12.5
#     Uninstalling certifi-2020.12.5:
#       Successfully uninstalled certifi-2020.12.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# datasets 1.13.3 requires huggingface-hub<0.1.0,>=0.0.19, but you have huggingface-hub 0.4.0 which is incompatible.
# ...

# %%
import selenium
from selenium import webdriver

# %% [markdown]
# >## Download Chrome driver [here](https://sites.google.com/chromium.org/driver/downloads?authuser=0)<br>
# Chrome version
# ![chrome_version.png](attachment:chrome_version.png)

# %% [markdown]
# >## Getting a security error
# Used this fix from Stack Overflow to get around `chromedriver` security error message
# ![chromedriver_securityErrorFix.png](attachment:chromedriver_securityErrorFix.png)

# %%
# getting path for downloaded chrome driver (manually type .xex)
PATH = '/Users/stephanie/tweetScrape/misc/chromedriver'

# create driver object
driver = webdriver.Chrome(executable_path = PATH)

# open a web page on Chrome
driver.get('https://www.amazon.com/')
# Out:
# <ipython-input-14-a73288b5e9de>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = PATH)

# %%
# printing page title
print(driver.title)
# Out:
# Amazon.com. Spend less. Smile more.

# %%
# closing web page
driver.quit()
